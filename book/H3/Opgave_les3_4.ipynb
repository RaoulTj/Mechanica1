# %% [markdown]
# # Uitwerkingen: Opgave 3

# %%
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.patches as patches

# Instellen van de balklengte en belastingen
balk_lengte = 10  # meters
verdeelde_belasting = 10  # kN/m
koppel_locatie = 6  # meters
koppel_waarde = 160  # kNm (met de klok mee)

# Coördinaten van de ondersteuningen
ondersteuning_links = 0  # Rolscharnier
ondersteuning_rechts = balk_lengte  # Gewone scharnier

# Instellen van de figuur
fig, ax = plt.subplots(figsize=(10, 4))

# Tekenen van de balk
ax.plot([0, balk_lengte], [0, 0], 'k', lw=4, label="Balk")

# Tekenen van de ondersteuningen als gevulde groene driehoeken
#ax.scatter(ondersteuning_links, -0.1, marker='^', s=300, color='green', label="Rolscharnier")
#ax.plot([-0.2, 0.2], [-0.25, -0.25], color='green')  # Meetlijn
#ax.scatter(ondersteuning_rechts, -0.1, marker='^', s=300, color='green', label="Scharnier")

# Inklemmen links (weergegeven met een dikke zwarte verticale lijn)
ax.plot([ondersteuning_links, ondersteuning_links], [-0.3, 0.3], 'k', lw=6)

# Inklemmen rechts (weergegeven met een dikke zwarte verticale lijn)
ax.plot([ondersteuning_rechts, ondersteuning_rechts], [-0.3, 0.3], 'k', lw=6)

# Tekenen van de verdeelde belasting met blauwe pijlen en label
#x_vals = np.linspace(0, balk_lengte, 9)  
#for x in x_vals:
#    ax.arrow(x, 0.5, 0, -0.3, head_width=0.2, head_length=0.2, fc='blue', ec='blue')
#ax.text(balk_lengte / 2, 0.7, r"$q = 10 kN/m$", fontsize=12, color='blue', ha='center')
#ax.plot([0, balk_lengte], [0.5, 0.5], color='blue')  # Meetlijn

# Tekenen van de punt belasting met blauwe pijlen en label
ax.arrow(5, 0.5, 0, -0.3, head_width=0.2, head_length=0.2, fc='blue', ec='blue')
ax.text(balk_lengte / 2, 0.7, r"$F = 10 kN$", fontsize=12, color='blue', ha='center')

# Tekenen van het koppel met cirkelpijlen en blauwe label
#ax.text(koppel_locatie, 0.6, r"$M = 160\ kNm$", fontsize=12, color='blue', ha='center')
#ax.arrow(koppel_locatie - 0.3, 0.2, 0.3, 0.3, head_width=0.1, head_length=0.1, fc='blue', ec='blue', linestyle='dashed')
#ax.arrow(koppel_locatie + 0.3, 0.2, -0.3, 0.3, head_width=0.1, head_length=0.1, fc='blue', ec='blue', linestyle='dashed')

# Tekenen van de maatvoering onder de balk
ax.plot([0, 0], [-0.5, -0.7], 'k')  # Begin meetlijn
#ax.plot([6, 6], [-0.5, -0.7], 'k')  # Begin meetlijn
ax.plot([balk_lengte, balk_lengte], [-0.5, -0.7], 'k')  # Eind meetlijn
ax.plot([0, balk_lengte], [-0.6, -0.6], 'k--')  # Meetlijn
ax.text(10 / 2, -0.7, " l = 10 m", fontsize=12, ha='center')
#ax.text(7, -0.7, "2 m", fontsize=12, ha='center')

# Maatvoering voor koppel locatie
#ax.plot([koppel_locatie, koppel_locatie], [-0.5, -0.4], 'k')  # Markering
#ax.text(koppel_locatie, -0.55, "6 m", fontsize=12, ha='center')

# Labels en titel in overeenstemming met template
ax.set_xlim(-1, balk_lengte + 1)
ax.set_ylim(-1, 1)
ax.set_xticks(np.arange(0, balk_lengte + 1, 1))
#ax.set_yticks([])
ax.set_xlabel(r"$x$", color="red", fontsize=14)
ax.set_ylabel(r"$z$", color="red", fontsize=14, rotation=0, labelpad=15)
ax.set_title("Mechanica schema")

# Koppelinstellingen
koppel_locatie = 6  # Positie van het koppel in meters
koppel_radius = 0.6  # Straal van de boog


# Bereken de positie van de pijlpunt op de boog
hoek_pijl = 90  # Pijlpunt bij 270 graden (onderkant boog)
pijl_x = 6.15 #koppel_locatie + (koppel_radius / 2) * np.cos(np.radians(hoek_pijl))
pijl_y = -0.25 #0.3 + (koppel_radius / 2) * np.sin(np.radians(hoek_pijl))

# Pijlpunt toevoegen aan de boog
#ax.add_patch(arc)
#ax.arrow(pijl_x, pijl_y, -0.02, -0.01, head_width=0.1, head_length=0.1, fc='blue', ec='blue')

# Label voor het koppel
#ax.text(koppel_locatie, -.45, r"$M = 160\ kNm$", fontsize=12, color='blue', ha='center')

# Legenda
#ax.legend()

# Assen uitschakelen
ax.axis('off')
#ax.grid()

# Creëer de boog voor het koppel
#arc = patches.Arc((koppel_locatie,-0), koppel_radius, koppel_radius, angle=270, theta1=20, theta2=180, color='blue', lw=2)
#ax.add_patch(arc)

# Plot weergeven
plt.show()

# %% [markdown]
# De functie voor de elastische lijn (doorbuigings) kan gevonden worden door gebruik te maken van;
#
# $EI \dfrac{d^4v}{dx^4}= 0$ en deze twee keer te integreren.

# %% [markdown]
# Voor snede I - tussen $[0 < x < 5]$ geldt;

# %% [markdown]
# \begin{align}
# EI\dfrac{d^4v}{dx^4} &= 0 \\
# EI\dfrac{d^3v}{dx^3} &= C_1 \\
# EI\dfrac{d^2v}{dx^2} &= C_1x + C_2 \\
# EI\dfrac{dv}{dx} &= \dfrac{1}{2}C_1x^2 + C_2x + C_3 \\
# EIv &= \dfrac{1}{6}C_1x^3 + \dfrac{1}{2}C_2x^2 + C_3x +C_4
# \end{align}

# %% [markdown]
# De integratie constanten $C_1$, $C_2$, $C_3$ en $C_4$ kunnen gevonden worden door gebruik te maken van de volgende randvoorwaardes.

# %% [markdown]
# Voor snede I - tussen $[0 < x < 5]$ geldt;
#
# Bij oplegging $A$ geldt;
#
# $x=0, v=0$

# %% [markdown]
# \begin{align}
#     EIv &= \dfrac{1}{6}C_1x^3 + \dfrac{1}{2}C_2x^2 + C_3x +C_4 \\
#     EI\cdot 0 &= \dfrac{1}{6}C_1 \cdot 0^3 + \dfrac{1}{2}C_2 \cdot 0^2 + C_3 \cdot 0 +C_4  \\
#     0 &= 0 + 0 +0 + C_4 \\
#     C_4 &= 0
# \end{align}

# %% [markdown]
# Voor snede I - tussen $[0 < x < 5]$ geldt;
#
# Bij oplegging $A$ geldt;
#
# $x=0, \dfrac{dv}{dx}=0$

# %% [markdown]
# \begin{align}
#     EI\dfrac{dv}{dx} &= \dfrac{1}{2}C_1x^2 + C_2x + C_3 \\
#     EI \cdot 0 &= \dfrac{1}{2}C_1 \cdot 0^2 + C_2 \cdot 0 + C_3 \\
#     EI \cdot 0 &= 0 +0 + C_3\\
#     C_3 &= 0
# \end{align}

# %% [markdown]
# Voor snede I - tussen $[0 < x < 5]$ geldt;
#
# Onder de punt belasting $F$ geldt;
#
# $x=\dfrac{1}{2}l, \dfrac{dv}{dx}=0$

# %% [markdown]
# \begin{align}
#     EI\dfrac{dv}{dx} &= \dfrac{1}{2}C_1x^2 + C_2x + C_3 \\
#     EI \cdot 0 &= \dfrac{1}{2}C_1 \cdot (\dfrac{1}{2}l)^2 + C_2 \cdot \dfrac{1}{2}l + C_3 \\
#     EI \cdot 0 &= \dfrac{1}{2}C_1 \cdot (\dfrac{1}{2}l)^2 + C_2 \cdot \dfrac{1}{2}l + 0 \\
#     EI \cdot 0 &= \dfrac{1}{2}C_1 \cdot (\dfrac{1}{2}l)^2 + C_2 \cdot \dfrac{1}{2}l \\
#     0 &= \dfrac{1}{2}C_1 \cdot \dfrac{1}{4}l^2 + C_2 \cdot \dfrac{1}{2}l \\
#     C_2 \cdot \dfrac{1}{2}l &= - \dfrac{1}{8}C_1 \cdot l^2   \\
#     C_2 &= - \dfrac{1}{4}C_1 \cdot l   \\
# \end{align}

# %% [markdown]
# Voor snede I - tussen $[0 < x < 5]$ geldt;
#
# Vanwege symmetrie geldt;
#
# \begin{align}
# EI\dfrac{d^3v}{dx^3} &= C_1 = \dfrac{1}{2}F
# \end{align}

# %% [markdown]
# $C_1$ invullen geeft $C_2$:

# %% [markdown]
# \begin{align}
#     C_2 &= - \dfrac{1}{4}C_1 \cdot l \\
#     C_2 &= - \dfrac{1}{4} (\dfrac{1}{2}F) \cdot l  \\
#  C_2 &= -\dfrac{1}{8}Fl \\
# \end{align}

# %% [markdown]
# De waardes voor $C_1$ en $C_2$ invullen geeft:

# %% [markdown]
# Voor snede I - tussen $[0 < x < 5]$ geldt;

# %% [markdown]
# \begin{align}
# EI\dfrac{d^4v}{dx^4} &= 0 \\
# EI\dfrac{d^3v}{dx^3} &= \dfrac{1}{2}F \\
# EI\dfrac{d^2v}{dx^2} &= \dfrac{1}{2}Fx -\dfrac{1}{8}Fl \\
# EI\dfrac{dv}{dx} &= \dfrac{1}{4}Fx^2 -\dfrac{1}{8}Flx  \\
# EIv &= \dfrac{1}{12}Fx^3 + \dfrac{1}{16}Flx^2
# \end{align}

# %% [markdown]
# Voor snede II - tussen $[5 < x < 10]$ geldt;

# %% [markdown]
# Dankzij symmetrie kan het probleem **alleen voor de linkerhelft** opgelost worden (bijvoorbeeld voor $0 \leq x \leq 5$), en vervolgens de oplossing spiegelen naar de rechterhelft.
#
# Hierdoor:
#
# - We hoeven slechts **één stuk** uit te rekenen (bijvoorbeeld $v_1(x)$).
# - De afgeleiden kunnen worden bepaald met de juiste **spiegelvoorwaarden**.

# %% [markdown]
# Vanwege symmetrie kan gebruik worden gemaakt van spiegelen dit geeft;

# %% [markdown]
# Doorbuiging is symmetrisch:
# \begin{align}
# v(x) = v(L-x)
# \end{align}
#
# Helling is antisymmetrisch:
# \begin{align}
# v'(x) = v'(L-x)
# \end{align}
#
# Buigmoment is symmetrisch:
# \begin{align}
# M(x) = M(L-x)
# \end{align}
#
# Dwarskracht is antisymmetrisch:
# \begin{align}
# V(x) = V(L-x)
# \end{align}

# %% [markdown]
# De functie voor de dwarskracht is bekend en kan nu getekend worden;

# %% [markdown]
# Voor snede I - tussen $[0 < x < 5]$ geldt;

# %% [markdown]
# \begin{align}
#     V = EI\dfrac{d^3v}{dx^3} &= \dfrac{1}{2}F \\
# \end{align}

# %% [markdown]
# Voor snede II - tussen $[5 \leq x \leq 10]$ geldt;

# %% [markdown]
# \begin{align}
#     V = EI\dfrac{d^3v}{dx^3} &= -\dfrac{1}{2}F \\
# \end{align}

# %%
import numpy as np
import matplotlib.pyplot as plt

# Gegeven parameters
L = 10       # Lengte van de balk (m)
x_C = 5     # Locatie van het koppel (m)
F = 10        # Punt belasting (kN, naar beneden)
q = 10     # Verdeelde belasting (kN/m, naar beneden)
M_C = 160   # Koppel (kNm, met de klok mee)
R_A = 20    # Reactiekracht bij A (kN)
R_B = 60    # Reactiekracht bij B (kN)

# Discretisatie van de balk
x_values = np.linspace(0, L, 500)
V_values = np.zeros_like(x_values)

# Momentverloop berekenen
for i, x in enumerate(x_values):
    if x < x_C:  # Links van het koppel
        V_values[i] = 4/8 * F
    else:  # Rechts van het koppel
        V_values[i] = -(1/2) * F  # Sprong in moment door koppel

# Plot de momentenlijn
plt.figure(figsize=(8, 5))
plt.plot(x_values, V_values, label="Dwarskrachtverloop V(x)", linewidth=2, color='blue')
plt.axhline(0, color='black', linewidth=0.8)
#plt.axvline(x_C, color='blue', linestyle='dashed', linewidth=1, label="Koppel bij x=6m")
plt.axvline(0, color='black', linewidth=2, label="Oplegging links (A)")
plt.axvline(L, color='black', linestyle='dashed', linewidth=0.8, label="Oplegging rechts (B)")
plt.xlabel("Positie langs de balk (m)")
plt.ylabel("Drarskracht V(x) [kN]")
plt.title("Dwarskrachtenlijn van de balk")
plt.grid(True, linestyle='--', alpha=0.6)
plt.legend()
plt.show()

# %% [markdown]
# $A_v$ kan gevonden worden door $x=0$ in te vullen in de functie voor de dwarskracht;

# %% [markdown]
# Voor snede I - tussen $[0 \leq x \leq 5]$ geldt;

# %% [markdown]
# \begin{align}
#     A_v = EI\dfrac{d^3v}{dx^3} &= \dfrac{1}{2}F \\
#     A_v &= \dfrac{1}{2} \cdot 10 \\
#     A_v &= 5 kN \\
# \end{align}

# %% [markdown]
# De functie voor het buigendmoment is bekend en kan nu getekend worden;

# %% [markdown]
# Voor snede I - tussen $[0 \leq x \leq 5]$ geldt;

# %% [markdown]
# \begin{align}
#     M = EI\dfrac{d^2v}{dx^2} &= \dfrac{1}{2}Fx -\dfrac{1}{8}Fl \\
# \end{align}

# %% [markdown]
# Voor snede II - tussen $[5 \leq x \leq 10]$ geldt;

# %% [markdown]
# \begin{align}
#     M = EI\dfrac{d^2v}{dx^2} &= \dfrac{1}{2}F(10-x) -\dfrac{1}{8}Fl \\
# \end{align}

# %%
import numpy as np
import matplotlib.pyplot as plt

# Gegeven parameters
L = 10       # Lengte van de balk (m)
x_C = 5     # Locatie van het koppel (m)
F = 10
q = 10     # Verdeelde belasting (kN/m, naar beneden)
M_C = 160   # Koppel (kNm, met de klok mee)
R_A = 20    # Reactiekracht bij A (kN)
R_B = 60    # Reactiekracht bij B (kN)

# Discretisatie van de balk
x_values = np.linspace(0, L, 500)
M_values = np.zeros_like(x_values)

# Momentverloop berekenen
for i, x in enumerate(x_values):
    if x < x_C:  # Links van het koppel
        M_values[i] =  (1 / 2) * F * x - (1 / 8) * F * L
    else:  # Rechts van het koppel
        M_values[i] = (1 / 2) * F * (10-x) - (1 / 8) * F * L

# Plot de momentenlijn
plt.figure(figsize=(8, 5))
plt.plot(x_values, M_values, label="Momentverloop M(x)", linewidth=2, color='blue')
plt.axhline(0, color='black', linewidth=0.8)
#plt.axvline(x_C, color='blue', linestyle='dashed', linewidth=1, label="Koppel bij x=6m")
plt.axvline(0, color='black', linewidth=2, label="Oplegging links (A)")
plt.axvline(L, color='black', linestyle='dashed', linewidth=0.8, label="Oplegging rechts (B)")
plt.xlabel("Positie langs de balk (m)")
plt.ylabel("Moment M(x) [kNm]")
plt.title("Momentenlijn van de balk")
plt.grid(True, linestyle='--', alpha=0.6)
plt.legend()
plt.show()

# %% [markdown]
# $M_a$ kan gevonden worden door $x=0$ in te vullen in de functie voor het moment;

# %% [markdown]
# \begin{align}
#     M_a = EI\dfrac{d^2v}{dx^2} &= -\dfrac{1}{2}F \cdot x - \dfrac{1}{8}Fl  \\
#     M_a &= -\dfrac{1}{2}F \cdot 0 - \dfrac{1}{8}Fl  \\
#     M_a &= - \dfrac{1}{8}Fl \\
#     M_a &= - \dfrac{1}{8} \cdot 10  \cdot 10 = -12,5 kNm
# \end{align}

# %% [markdown]
# De functie van de helling is bekend en kan nu getekend worden;

# %% [markdown]
# Voor snede I - tussen $[0 \leq x \leq 5]$ geldt;

# %% [markdown]
# \begin{align}
#     EI\dfrac{dv}{dx} &= \dfrac{1}{4}Fx^2 -\dfrac{1}{8}Flx
# \end{align}

# %% [markdown]
# Voor snede II - tussen $[5 \leq x \leq 10]$ geldt;

# %% [markdown]
# \begin{align}
#     EI\dfrac{dv}{dx} &= \dfrac{1}{4}F(10-x)^2 -\dfrac{1}{8}Fl(10-x)
# \end{align}

# %%
import numpy as np
import matplotlib.pyplot as plt

# Gegeven parameters
L = 10       # Lengte van de balk (m)
x_C = 5     # Locatie van het koppel (m)
q = 10     # Verdeelde belasting (kN/m, naar beneden)
F = 10
M_C = 160   # Koppel (kNm, met de klok mee)
R_A = 20    # Reactiekracht bij A (kN)
R_B = 60    # Reactiekracht bij B (kN)

# Discretisatie van de balk
x_values = np.linspace(0, L, 500)
EIv_values = np.zeros_like(x_values)

# Momentverloop berekenen
for i, x in enumerate(x_values):
    if x < x_C:  # Links van het koppel
        EIv_values[i] = (1/4) * F * x**2 - (1/8) * F * L * x
    else:  # Rechts van het koppel
        EIv_values[i] = -(1/4) * F * (10-x)**2 + (1/8) * F * L * (10-x)

# Plot de momentenlijn
plt.figure(figsize=(8, 5))
plt.plot(x_values, EIv_values, label="EIv(x)", linewidth=2, color='blue')
plt.axhline(0, color='black', linewidth=0.8)
#plt.axvline(x_C, color='blue', linestyle='dashed', linewidth=1, label="Koppel bij x=6m")
plt.axvline(0, color='black', linewidth=2, label="Oplegging links (A)")
plt.axvline(L, color='black', linestyle='dashed', linewidth=0.8, label="Oplegging rechts (B)")
plt.xlabel("Positie langs de balk [m]")
plt.ylabel("EIv(x) [m]")
plt.title("Helling van de balk")
plt.grid(True, linestyle='--', alpha=0.6)
plt.legend()
plt.show()

# %% [markdown]
# De functie van de elastischelijn (doorbuigingslijn) is bekend en kan nu getekend worden;

# %% [markdown]
# Voor snede I - tussen $[0 \leq x \leq 5]$ geldt;

# %% [markdown]
# \begin{align}
# E   Iv &= \dfrac{1}{12}Fx^3 + \dfrac{1}{16}Flx^2
# \end{align}

# %% [markdown]
# Voor snede II - tussen $[5 \leq x \leq 10]$ geldt;

# %% [markdown]
# \begin{align}
# E   Iv &= \dfrac{1}{12}F(10-x)^3 + \dfrac{1}{16}Fl(10-x)^2
# \end{align}

# %%
import numpy as np
import matplotlib.pyplot as plt

# Gegeven parameters
L = 10       # Lengte van de balk (m)
x_C = 5     # Locatie van het koppel (m)
F = 10
q = 10     # Verdeelde belasting (kN/m, naar beneden)
M_C = 160   # Koppel (kNm, met de klok mee)
R_A = 20    # Reactiekracht bij A (kN)
R_B = 60    # Reactiekracht bij B (kN)

# Discretisatie van de balk
x_values = np.linspace(0, L, 500)
EIv_values = np.zeros_like(x_values)

# Momentverloop berekenen
for i, x in enumerate(x_values):
    if x < x_C:  # Links van het koppel
        EIv_values[i] = (1/12) * F * x**3 - (1/16) * F * L * x**2
    else:  # Rechts van het koppel
        EIv_values[i] = (1/12) * F * (10-x)**3 - (1/16) * F * L * (10-x)**2

# Plot de momentenlijn
plt.figure(figsize=(8, 5))
plt.plot(x_values, EIv_values, label="EIv(x)", linewidth=2, color='blue')
plt.axhline(0, color='black', linewidth=0.8)
#plt.axvline(x_C, color='blue', linestyle='dashed', linewidth=1, label="Koppel bij x=6m")
plt.axvline(0, color='black', linewidth=2, label="Oplegging links (A)")
plt.axvline(L, color='black', linestyle='dashed', linewidth=0.8, label="Oplegging rechts (B)")
plt.xlabel("Positie langs de balk [m]")
plt.ylabel("EIv(x) [m]")
plt.title("Doorbuiging van de balk")
plt.grid(True, linestyle='--', alpha=0.6)
plt.legend()
plt.show()
